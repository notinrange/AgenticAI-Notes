# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state : BlogState)->BlogState:
    title = state['title']

    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    state['outline'] = outline
    return state

# %%
def create_blog(state : BlogState)->BlogState:
    title = state['title']
    outline = state['outline']
    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'
    content = model.invoke(prompt).content

    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline' )
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)


workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# Artificial Intelligence (AI) has been gaining momentum globally, transforming industries and revolutionizing the way we live and work. India, with its vast talent pool, growing economy, and government support, has emerged as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool.
#
# **Government Initiatives and Policies: A Catalyst for AI Growth**
#
# The Indian government has been proactive in promoting AI development, recognizing its potential to drive economic growth, improve governance, and enhance competitiveness. The National AI Mission, launched by NITI Aayog, aims to make India a global leader in AI by 2025. The Digital India initiative and Make in India program have also played a crucial role in promoting AI adoption and development. Key policies and regulations, such as data protection laws, intellectual property protection, and tax incentives for AI startups, have created a conducive environment for AI growth.
#
# The government has also established several research institutions and centers, such as the IIT Delhi's AI Lab, to focus on AI research and development. These initiatives have not only encouraged innovation but also attracted investments from global companies and startups. For instance, the Indian government's AI startup fund has invested in several AI-based startups, providing them with the necessary resources to scale up their operations.
#
# **AI Adoption in Key Industries: Transforming the Way We Work**
#
# AI is being adopted in various industries, transforming the way we work and live. In healthcare, AI-powered telemedicine platforms are revolutionizing patient care, while medical diagnosis and patient data analysis are becoming more accurate and efficient. In finance, chatbots and predictive analytics are enhancing customer experience and risk management. In education, personalized learning and adaptive assessments are improving student outcomes, while intelligent tutoring systems are making learning more engaging and effective.
#
# Indian companies and startups are also leveraging AI in these industries. For example, Apollo Hospitals has launched an AI-powered chatbot to provide patients with personalized health advice, while HDFC Bank has implemented an AI-based system to detect and prevent cyber attacks. In education, companies like BYJU's and Vedantu are using AI to create personalized learning plans for students.
#
# **AI Research and Development in India: A Hub for Innovation**
#
# India's AI research ecosystem is thriving, with top research institutions and universities, such as IITs and IIITs, focusing on AI research. Research centers and labs, such as IIT Delhi's AI Lab, are working on key areas of AI research, including Natural Language Processing (NLP), Computer Vision, Machine Learning (ML), and Robotics.
#
# Indian researchers are making significant contributions to AI research, with several papers being published in top-tier conferences and journals. The Indian government has also launched several initiatives to promote AI research, such as the AI for India initiative, which aims to develop AI solutions for social good.
#
# **AI Talent and Skills Development: Meeting the Growing Demand**
#
# The demand for AI professionals is growing rapidly, with Indian companies and startups looking for skilled talent to drive their AI initiatives. However, there is a significant skill gap in the market, with many professionals lacking the necessary skills to work on AI projects.
#
# To address this gap, several initiatives have been launched to develop AI skills, including online courses and certification programs, university programs and degrees in AI and related fields, and corporate training and upskilling programs. For example, Coursera and edX have launched several AI-related courses, while universities like IIT Delhi and IIIT Hyderabad have launched AI-focused programs.
#
# **Challenges and Opportunities: Navigating the AI Landscape**
#
# While India has made significant progress in AI adoption and development, there are several challenges that need to be addressed. Data quality and availability are significant concerns, with many Indian companies struggling to access high-quality data to train their AI models. Infrastructure and computational resources are also a challenge, with many companies lacking the necessary resources to support large-scale AI deployments.
#
# However, despite these challenges, there are significant opportunities for India to leverage AI. AI can drive economic growth and job creation, improve governance and public services, and enhance competitiveness in global markets. The Indian government has launched several initiatives to address these challenges, such as the Data for AI initiative, which aims to provide access to high-quality data for AI research and development.
#
# **Conclusion: India's AI Future**
#
# In conclusion, India is experiencing a significant rise in AI adoption and development, driven by government initiatives, technological advancements, and a growing talent pool. While there are challenges to be addressed, the opportunities for India to leverage AI are significant. As the Indian government continues to invest in AI research and development, and companies and startups continue to innovate and adopt AI, India is poised to become a global leader in AI.
#
# The future of AI in India is exciting, with several initiatives and developments on the horizon. The Indian government has launched several initiatives to promote AI adoption and development, including the AI for India initiative, which aims to develop AI solutions for social good. Companies and startups are also innovating and adopting AI, with several AI-based products and services being launched in the market.
#
# In the next few years, we can expect to see significant advancements in AI research and development, with Indian researchers making significant contributions to the field. The demand for AI professionals will continue to grow, with companies and startups looking for skilled talent to drive their AI initiatives. As India continues to navigate the AI landscape, it is essential to address the challenges and leverage the opportunities to realize the full potential of AI.
#
# The rise of AI in India is a testament to the country's potential to innovate and grow. As we look to the future, it is clear that AI will play a significant role in shaping India's economy, society, and polity. With continued investment, innovation, and collaboration, India can become a global leader in AI, driving economic growth, improving governance, and enhancing competitiveness in global markets.
